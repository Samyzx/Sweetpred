# %%
from mordred import Calculator, descriptors
from rdkit import Chem

calc=Calculator(descriptors, ignore_3D=True)

len(calc.descriptors)
# Out:
# 1613

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('Data/SweetpredDB.csv')
df.head()
# Out:
#                         Name Test_ID  \
# 0       1',4',6'-3Cl-sucrose  test_1
# 1          1',4'-2Cl-sucrose  test_2
# 2          1',6'-2Cl-sucrose  test_3
# 3              1'-Cl-sucrose  test_4
# 4  4'-Br-4,1',6'-3Cl-sucrose  test_5
#
#                                             Smiles  Sweetness  logSw
# 0   ClC1C(O)[C@@](OC1CCl)(OC1OC(CO)C(O)C(O)C1O)CCl    10000.0   4.00
# 1    ClC1C(O)[C@@](OC1CO)(OC1OC(CO)C(O)C(O)C1O)CCl     3000.0   3.48
# 2     ClCC1O[C@](OC2OC(CO)C(O)C(O)C2O)(CCl)C(O)C1O     7800.0   3.89
# 3      ClC[C@]1(OC(CO)C(O)C1O)OC1OC(CO)C(O)C(O)C1O     2000.0   3.30
# 4  BrC1C(O)[C@@](OC1CCl)(OC1OC(CO)C(Cl)C(O)C1O)CCl   325000.0   5.51

# %%
# making a seperate .smi file of Test_ID and Smiles
df_smiles = df['Smiles']
from padelpy import from_smiles

# %%
# seperate df_smiles in slabs of 200
df_smiles1 = df_smiles[0:200]
df_smiles2 = df_smiles[200:400]
df_smiles3 = df_smiles[400:600]
df_smiles4 = df_smiles[600:len(df_smiles)]

# %%
# convert df_smiles to list
smiles1 = df_smiles1.tolist()
_ = from_smiles(smiles1, descriptors=True, fingerprints=False, timeout=100000, threads=4, output_csv='Descriptors1.csv')

# %%
smiles2 = df_smiles2.tolist()
_ = from_smiles(smiles2, descriptors=True, fingerprints=False, timeout=100000, threads=3, output_csv='Descriptors2.csv')
